# %% [markdown]
# # M(RT)$^2$

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np
import matplotlib.pyplot as plt
points=100
T = np.linspace(0.2,3.0,num=points)
beta = 1/T
J = 1.0
Ns = 50
th = np.tanh(J/T)
thN= th**Ns
ch = 1/th
e = -J*( th + ch*thN )/( 1 + thN )
plt.plot(T, e)
plt.title('Ising 1D, internal energy')
plt.xlabel('T')
plt.ylabel('U/N')
plt.show()

heat=((beta*J)**2)*(((1+thN+(Ns-1)*(th**2)+(Ns-1)*(ch**2)*thN)/(1+thN))-Ns*((th+ch*thN)/(1+thN))**2)
plt.plot(T, heat)
plt.title('Ising 1D, Heat capacity')
plt.xlabel('T')
plt.ylabel('C')
plt.show()

# %%
h=0.02 #external field
b = 1/T

l1 = np.exp(b*J)*np.cosh(b*h)+np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J))
l2 = np.exp(b*J)*np.cosh(b*h)-np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J))
Z = l1**Ns + l2**Ns
M = (np.exp(b*J)*np.sinh(b*h)*((l1**(Ns-1))*(1+np.exp(b*J)*np.cosh(b*h)/np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J))) 
        + (l2**(Ns-1))*(1-np.exp(b*J)*np.cosh(b*h)/np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J)))))/(Z)
plt.plot(T, M)
plt.title('Ising 1D, magnetization M with h = 0.02')
plt.xlabel('T')
plt.ylabel('$M$')
plt.show()

# %%
acc_mc=pd.read_csv('NSL_SIMULATOR/OUTPUT/MRT2/acceptance.dat',delimiter=r"\s+")
acc_mc
# Out:
#     #N_BLOCK:  ACCEPTANCE:
# 0           1     0.238553
# 1           2     0.238328
# 2           3     0.238116
# 3           4     0.237995
# 4           5     0.237599
# 5           6     0.237451
# 6           7     0.237650
# 7           8     0.238060
# 8           9     0.238283
# 9          10     0.238202
# 10         11     0.238316
# 11         12     0.238217
# 12         13     0.238152
# 13         14     0.238257
# 14         15     0.238080
# 15         16     0.237956
# 16         17     0.238042
# 17         18     0.238094
# 18         19     0.238031
# 19         20     0.238050

# %%
plt.plot(acc_mc['#N_BLOCK:'],acc_mc['ACCEPTANCE:'])
plt.xlabel('block')
plt.ylabel('acceptance')

plt.grid(True)

# %%
import os

os.listdir('NSL_SIMULATOR/OUTPUT/MRT2/')
# Out:
# ['specific_heat.dat',
#  'output.dat',
#  'seed.out',
#  'total_energy.dat',
#  'susceptibility.dat',
#  'CONFIG',
#  'acceptance.dat',
#  'magnetization.dat']

# %%
cvs=[]
cvs_err=[]
for i in range(1, 6):

    cv=pd.read_csv(f'NSL_SIMULATOR/OUTPUT/specific_heat_temp{i*0.5}.dat', delimiter=r'\s+',
                  skiprows=1,
                  names=['#block', 'actual_cv', 'cv_ave', 'error'] 
    )

    #print(cv)

    """plt.plot(cv['#block'], cv['actual_cv'], label='actual')
    plt.errorbar(x=cv['#block'], y=cv['cv_ave'], yerr=cv['error'], label='avg')
    plt.grid(True)
    plt.xlabel('#blocks')
    plt.ylabel('cv')

    plt.legend()

    plt.show()
    """
    cvs.append(cv['cv_ave'][len(cv)-1])
    cvs_err.append(cv['error'][len(cv)-1])

    
    
plt.errorbar(x=[i*0.5 for i in range(1, 6)], y=cvs, yerr=cvs_err, marker='o')
plt.plot(T, heat)

plt.xlabel('T')
plt.ylabel('cv')
# Out:
# Text(0, 0.5, 'cv')

# %%
cvs=[]
cvs_err=[]
for i in range(1, 6):

    mag=pd.read_csv(f'NSL_SIMULATOR/OUTPUT/magnetization_temp{i*0.5}.dat', delimiter=r'\s+',
                  skiprows=1,
                  names=['#block', 'actual_mag', 'mag_ave', 'error'] 
    )

    #print(cv)
    """
    plt.plot(cv['#block'], cv['actual_cv'], label='actual')
    plt.errorbar(x=cv['#block'], y=cv['cv_ave'], yerr=cv['error'], label='avg')
    plt.grid(True)
    plt.xlabel('#blocks')
    plt.ylabel('magnetization')

    plt.legend()

    plt.show()
    """
    cvs.append(mag['mag_ave'][len(mag)-1])
    cvs_err.append(mag['error'][len(mag)-1])

    
    
plt.errorbar(x=[i*0.5 for i in range(1, 6)], y=cvs, yerr=cvs_err, marker='o')
plt.plot(T, M)

plt.xlabel('T')
plt.ylabel('cv')
# Out:
# Text(0, 0.5, 'cv')

# %%
cvs_err
# Out:
# [0.00421852, 9.81296e-05, 3.80894e-05, 2.88815e-05, 2.47063e-05]

# %%
sus=pd.read_csv('NSL_SIMULATOR/OUTPUT/MRT2/susceptibility.dat', delimiter=r'\s+',
              skiprows=1,
              names=['#block', 'actual_sus', 'sus_ave', 'error'] 
)



plt.plot(sus['#block'], sus['actual_sus'], label='actual')
plt.errorbar(x=sus['#block'], y=sus['sus_ave'], yerr=sus['error'], label='avg')
plt.grid(True)
plt.xlabel('#blocks')
plt.ylabel('sus')

plt.legend()

plt.show()

# %%
mag=pd.read_csv('NSL_SIMULATOR/OUTPUT/MRT2/magnetization.dat', delimiter=r'\s+',
              skiprows=1,
              names=['#block', 'actual_mag', 'mag_ave', 'error'] 
)



plt.plot(mag['#block'], mag['actual_mag'], label='actual')
plt.errorbar(x=mag['#block'], y=mag['mag_ave'], yerr=mag['error'], label='avg')
plt.grid(True)
plt.xlabel('#blocks')
plt.ylabel('mag')

plt.legend()

plt.show()

# %%
ten=pd.read_csv('NSL_SIMULATOR/OUTPUT/MRT2/total_energy.dat', delimiter=r'\s+',
              skiprows=1,
              names=['#block', 'actual_ten', 'ten_avg', 'error'] 
)

ten

plt.plot(ten['#block'], ten['actual_ten'], label='actual')
plt.errorbar(x=ten['#block'], y=ten['ten_avg'], yerr=ten['error'], label='avg')
plt.grid(True)
plt.xlabel('#blocks')
plt.ylabel('ten')

plt.legend()

plt.show()

# %%
ten
# Out:
#     #block  actual_ten   ten_avg     error
# 0        1   -0.761504 -0.761504  0.000000
# 1        2   -0.761060 -0.761282  0.000157
# 2        3   -0.761964 -0.761509  0.000213
# 3        4   -0.763620 -0.762037  0.000484
# 4        5   -0.764588 -0.762547  0.000599
# 5        6   -0.763224 -0.762660  0.000509
# 6        7   -0.761500 -0.762494  0.000463
# 7        8   -0.758880 -0.762043  0.000585
# 8        9   -0.759968 -0.761812  0.000564
# 9       10   -0.762880 -0.761919  0.000517
# 10      11   -0.761304 -0.761863  0.000473
# 11      12   -0.762676 -0.761931  0.000439
# 12      13   -0.762856 -0.762002  0.000411
# 13      14   -0.760552 -0.761898  0.000394
# 14      15   -0.765072 -0.762110  0.000421
# 15      16   -0.764192 -0.762240  0.000414
# 16      17   -0.760560 -0.762141  0.000401
# 17      18   -0.760940 -0.762074  0.000385
# 18      19   -0.763008 -0.762124  0.000368
# 19      20   -0.761656 -0.762100  0.000350

# %%
cvs=[]
cvs_err=[]
for i in range(1, 6):

    sus=pd.read_csv(f'NSL_SIMULATOR/OUTPUT/susceptibility_temp{i*0.5}.dat', delimiter=r'\s+',
                  skiprows=1,
                  names=['#block', 'actual_sus', 'sus_ave', 'error'] 
    )

    #print(cv)
    """
    plt.plot(cv['#block'], cv['actual_cv'], label='actual')
    plt.errorbar(x=cv['#block'], y=cv['cv_ave'], yerr=cv['error'], label='avg')
    plt.grid(True)
    plt.xlabel('#blocks')
    plt.ylabel('magnetization')

    plt.legend()

    plt.show()
    """
    cvs.append(mag['sus_ave'][len(sus)-1])
    cvs_err.append(mag['error'][len(sus)-1])

    
    
plt.errorbar(x=[i*0.5 for i in range(1, 6)], y=cvs, yerr=cvs_err, marker='o')
plt.plot(T, M)

plt.xlabel('T')
plt.ylabel('cv')
